# %% [markdown]
# Q. 다음 출력 값으로 올바른 것은?
# ```
# l = [100, 200, 300]
# print(type(l))
# ```
# 1)  class 'str'<br>
# 2)  class 'int'<br>
# 3)  class 'list'<br>
# 4)  class 'tuple'

# %%
l = [100, 200, 300]
print(type(l))

# 정답 3번
# Out:
# <class 'list'>
