# %% [markdown]
# Q. for를 사용하여 1부터 100까지 모두 더하는 Code를 `<pass>` 부분에 완성하세요.
#
# ```
# s = 0
#
# <pass>
#
# print(s)
# ```

# %%
s = 0

for i in range(1, 101):
# for i in range(101):
  s += i

print(s)
# Out:
# 5050
