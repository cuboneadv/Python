# %% [markdown]
# Q. 신학기가 시작되고, 아이들이 돌아가면서 자기소개를 하기로 했습니다. 만약 입력으로 `김다정`이라는 이름이 주어지면
#
# ```
# 안녕하세요. 저는 김다정입니다.
# ```
# 라고 출력하게 해주세요.
# ```
# >> 입력
# 김승주
# ```
# ```
# >> 출력
# 안녕하세요. 저는 김승주입니다.
# ```

# %%
name = input("이름을 입력하세요: ")

print(f"안녕하세요. 저는 {name}입니다.")
# Out:
# 이름을 입력하세요: 탕구리
# 안녕하세요. 저는 탕구리입니다.
