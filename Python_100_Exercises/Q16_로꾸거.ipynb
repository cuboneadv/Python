# %% [markdown]
# Q. 문장이 입력되면 거꾸로 출력하는 프로그램을 만들어 봅시다.
# ```
# >> 입력
# 거꾸로
# ```
# ```
# >> 출력
# 로꾸거
# ```

# %%
sen = input("문장을 입력하세요: ")

# for i in range(len(sen) - 1, -1, -1):
for i in range(-1, -(len(sen) + 1), -1):
    print(sen[i], end = '')
# Out:
# 문장을 입력하세요: 호크아이 상향해주세요.
# .요세주해향상 이아크호
