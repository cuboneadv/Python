# %% [markdown]
# Q. 다음 중 set을 만드는 방법이 아닌 것은?
# ```
# 1) x = {1, 2, 3, 5, 6, 7}
# 2) x = {}
# 3) x = set('Python')
# 4) x = set(range(5))
# 5) x = set()
# ```

# %%
x = {1, 2, 3, 5, 6, 7}
x = {}
x = set('Python')
x = set(range(5))
x = set()
