# %% [markdown]
# Q. 원의 넓이는 `반지름의 길이 x 반지름의 길이 x 3.14`로 구할 수 있습니다.
#
# **반지름의 길이가 입력되면 원의 넓이를 반환하는 함수**를 만들어 주세요.
# ```
# >> 입력
# 7
# ```
# ```
# >> 출력
# 153.86
# ```

# %%
r = int(input("반지름의 길이를 입력하세요: "))
area = r**2 * 3.14

print(f"원의 넓이는 {area}입니다.")
# Out:
# 반지름의 길이를 입력하세요: 77
# 원의 넓이는 18617.06입니다.
