# %% [markdown]
# Q. 다음 리스트의 내장함수의 시간 복잡도가 `O(1)`이 아닌 것은?
# ```
# 1)  l[i]
# 2)  l.append(5)
# 3)  l[a:b]
# 4)  l.pop()
# 5)  l.clear()
# ```

# %%
# 정답 3번

# %% [markdown]
# ```
# l[a:b]
# ```
# ```
# 시간 복잡도: O(b-a)
# - 리스트의 슬라이싱 연산은 슬라이스의 길이에 비례하는 시간이 걸림
# - 슬라이스의 크기가 커질수록 시간이 더 걸리므로 시간 복잡도는 O(1)이 아님
# ```
