# %% [markdown]
# Q. **문자열을 입력받았을 때 단어의 개수를 출력하는 프로그램**을 작성해 주세요.
# ```
# >> 입력
# 저 넓은 세상을 네 눈앞에 그려봐 네 진심을 느껴봐
# ```
# ```
# >> 출력
# 9
# ```

# %%
text = input("문자열을 입력해주세요: ")
num_words = len(text.split())

print(num_words)
# Out:
# 문자열을 입력해주세요: 저 넓은 세상을 네 눈앞에 그려봐 네 진심을 느껴봐
# 9
