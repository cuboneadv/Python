# %% [markdown]
# Q. 1부터 9까지의 숫자 중 하나를 입력하면, 해당 숫자의 구구단 결과를 한 줄에 출력하는 프로그램을 작성해 주세요.
# ```
# >> 입력
# 2
# ```
# ```
# >> 출력
# 2 4 6 8 10 12 13 16 18
# ```

# %%
number = int(input("1부터 9까지의 숫자 중 하나를 입력하세요: "))

for i in range(1, 10):
    print(number * i, end = ' ')
# Out:
# 1부터 9까지의 숫자 중 하나를 입력하세요: 3
# 3 6 9 12 15 18 21 24 27
