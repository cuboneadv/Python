# %% [markdown]
# Q. 유정이는 모든 `q`를 `e`로 바꾸는 프로그램을 작성하려고 합니다.
#
# **문장이 입력되면 모든 `q`를 `e`로 바꾸는 프로그램을 작성해 주세요.**
# ```
# >> 입력
# querty
# ```
# ```
# >> 출력
# euerty
# ```
# ```
# >> 입력
# La viq qn rosq
# ```
# ```
# >> 출력
# La vie en rose
# ```

# %%
text = input("문장을 입력해 주세요: ")
replaced_text = text.replace('q', 'e')

print(f"수정된 문장은 {replaced_text} 입니다.")
# Out:
# 문장을 입력해 주세요: La viq qn rosq
# 수정된 문장은 La vie en rose 입니다.
