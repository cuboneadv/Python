# %% [markdown]
# Q. 다음 변수 a를 `print(type(a))`로 넣었을 때 출력될 값과의 연결이 알맞지 않은 것은?
#
# 1)  입력 : a =1,   출력 : class 'int'
#
# 2)  입력 : a = 2.22,   출력 : class 'float'
#
# 3)  입력 : a = 'p',   출력 : class 'char'
#
# 4)  입력 : a = [1, 2, 3],   출력 : class 'list'

# %%
a = 'p'
print(type(a))

# 정답 3번

# Python에서는 단일 문자든 여러 문자든 모두 str 타입으로 다루어짐
# Out:
# <class 'str'>
