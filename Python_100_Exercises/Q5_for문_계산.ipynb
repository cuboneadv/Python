# %% [markdown]
# Q. 다음 코드의 출력 값으로 알맞은 것은?
# ```
# a = 10
# b = 2
# for i in range(1, 5, 2):
#     a += i
#
# print(a + b)
# ```
# 1)  10
#
# 2)  12
#
# 3)  14
#
# 4)  16

# %%
a = 10
b = 2
for i in range(1, 5, 2):
    a += i

print(a + b)

# 정답 4번

# range는 마지막 범위 수 포함하지 않음
# Out:
# 16
